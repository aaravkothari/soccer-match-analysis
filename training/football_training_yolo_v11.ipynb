# %%
from roboflow import Roboflow
from dotenv import load_dotenv
import os

load_dotenv()

rf = Roboflow(api_key=os.getenv('ROBOFLOW_KEY'))
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-1 to yolov11:: 100%|██████████| 147802/147802 [00:06<00:00, 24398.75it/s]
# Extracting Dataset Version Zip to football-players-detection-1 in yolov11:: 100%|██████████| 1338/1338 [00:01<00:00, 1208.89it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")
model.train(data=f"{dataset.location}\\data.yaml", epochs=100, imgsz=640, device='cuda')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 18.1MB/s]
# Ultralytics 8.3.159  Python-3.13.5 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 1000 Ada Generation Laptop GPU, 6141MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\aarav\Dev\Test\gpu-usage\training\football-players-detection-1\data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs\detect\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431452  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,620 parameters, 2,590,604 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 14.32.1 MB/s, size: 228.7 KB)
# train: Scanning C:\Users\aarav\Dev\Test\gpu-usage\training\football-players-detection-1\train\labels... 612 images, 0 backgrounds, 0 corrupt: 100%|██████████| 612/612 [00:01<00:00, 311.91it/s]
# train: New cache created: C:\Users\aarav\Dev\Test\gpu-usage\training\football-players-detection-1\train\labels.cache
# val: Fast image access  (ping: 0.10.0 ms, read: 10.62.9 MB/s, size: 208.1 KB)
# val: Scanning C:\Users\aarav\Dev\Test\gpu-usage\training\football-players-detection-1\valid\labels... 38 images, 0 backgrounds, 0 corrupt: 100%|██████████| 38/38 [00:00<00:00, 252.02it/s]
# val: New cache created: C:\Users\aarav\Dev\Test\gpu-usage\training\football-players-detection-1\valid\labels.cache
# Plotting labels to runs\detect\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs\detect\train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.89G      1.682      2.816     0.8882        131        640: 100%|██████████| 39/39 [00:12<00:00,  3.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.03it/s]
#                    all         38        905   0.000351    0.00265   0.000199   5.24e-05
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.92G      1.567      1.307     0.8555        106        640: 100%|██████████| 39/39 [00:09<00:00,  3.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  5.00it/s]
#                    all         38        905     0.0399       0.31      0.193     0.0973
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.93G      1.483      1.142     0.8386        162        640: 100%|██████████| 39/39 [00:10<00:00,  3.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.65it/s]
#                    all         38        905       0.89      0.164      0.246      0.129
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      3.14G      1.463      1.081     0.8364        199        640: 100%|██████████| 39/39 [00:12<00:00,  3.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.92it/s]
#                    all         38        905      0.828      0.259      0.287      0.156
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      3.35G      1.532      1.052     0.8373        260        640: 100%|██████████| 39/39 [00:12<00:00,  3.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.46it/s]
#                    all         38        905      0.765      0.271       0.32       0.18
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.92G       1.41     0.9675     0.8319        172        640: 100%|██████████| 39/39 [00:12<00:00,  3.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.26it/s]
#                    all         38        905      0.653      0.332      0.378      0.217
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.92G      1.329     0.9198     0.8352        577        640:  26%|██▌       | 10/39 [00:02<00:07,  3.73it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 from ultralytics import YOLO
#       3 model = YOLO("yolo11n.pt")
# ----> 4 model.train(data=f"{dataset.location}\\data.yaml", epochs=100, imgsz=640, device='cuda')
#
# File c:\Users\aarav\Dev\Test\gpu-usage\myenv\Lib\site-packages\ultralytics\engine\model.py:797, in Model.train(self, trainer, **kwargs)
#     794     self.model = self.trainer.model
#     796 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 797 self.trainer.train()
#     798 # Update model and cfg after training
#     799 if RANK in {-1, 0}:
#
# File c:\Users\aarav\Dev\Test\gpu-usage\myenv\Lib\site-packages\ultralytics\engine\trainer.py:227, in BaseTrainer.train(self)
#     224         ddp_cleanup(self, str(file))
#     226 else:
# --> 227     self._do_train(world_size)
#
# File c:\Users\aarav\Dev\Test\gpu-usage\myenv\Lib\site-packages\ultralytics\engine\trainer.py:419, in BaseTrainer._do_train(self, world_size)
#     417 # Optimize - https://pytorch.org/docs/master/notes/amp_examples.html
#     418 if ni - last_opt_step >= self.accumulate:
# --> 419     self.optimizer_step()
#     420     last_opt_step = ni
#     422     # Timed stopping
#
# File c:\Users\aarav\Dev\Test\gpu-usage\myenv\Lib\site-packages\ultralytics\engine\trainer.py:641, in BaseTrainer.optimizer_step(self)
#     639 """Perform a single step of the training optimizer with gradient clipping and EMA update."""
#     640 self.scaler.unscale_(self.optimizer)  # unscale gradients
# --> 641 torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=10.0)  # clip gradients
#     642 self.scaler.step(self.optimizer)
#     643 self.scaler.update()
#
# File c:\Users\aarav\Dev\Test\gpu-usage\myenv\Lib\site-packages\torch\nn\utils\clip_grad.py:38, in _no_grad.<locals>._no_grad_wrapper(*args, **kwargs)
#      36 def _no_grad_wrapper(*args, **kwargs):
#      37     with torch.no_grad():
# ---> 38         return func(*args, **kwargs)
#
# File c:\Users\aarav\Dev\Test\gpu-usage\myenv\Lib\site-packages\torch\nn\utils\clip_grad.py:219, in clip_grad_norm_(parameters, max_norm, norm_type, error_if_nonfinite, foreach)
#     217     parameters = list(parameters)
#     218 grads = [p.grad for p in parameters if p.grad is not None]
# --> 219 total_norm = _get_total_norm(grads, norm_type, error_if_nonfinite, foreach)
#     220 _clip_grads_with_norm_(parameters, max_norm, total_norm, foreach)
#     221 return total_norm
#
# File c:\Users\aarav\Dev\Test\gpu-usage\myenv\Lib\site-packages\torch\nn\utils\clip_grad.py:38, in _no_grad.<locals>._no_grad_wrapper(*args, **kwargs)
#      36 def _no_grad_wrapper(*args, **kwargs):
#      37     with torch.no_grad():
# ---> 38         return func(*args, **kwargs)
#
# File c:\Users\aarav\Dev\Test\gpu-usage\myenv\Lib\site-packages\torch\nn\utils\clip_grad.py:91, in _get_total_norm(tensors, norm_type, error_if_nonfinite, foreach)
#      87 for (device, _), ([device_tensors], _) in grouped_tensors.items():
#      88     if (foreach is None and _has_foreach_support(device_tensors, device)) or (
#      89         foreach and _device_has_foreach_support(device)
#      90     ):
# ---> 91         norms.extend(torch._foreach_norm(device_tensors, norm_type))
#      92     elif foreach:
#      93         raise RuntimeError(
#      94             f"foreach=True was passed, but can't use the foreach API on {device.type} tensors"
#      95         )
#
# KeyboardInterrupt:
